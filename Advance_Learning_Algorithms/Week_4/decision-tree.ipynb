# %% [markdown]
# <a href="https://www.kaggle.com/code/ibrahelsheikh/decision-tree?scriptVersionId=143734546" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **from scracth**

# %% [markdown]
# # Decision tree Algorithm
#
# ## As we know Decision tree is one of the AI algorithms
# ## So this will explain it in detail
